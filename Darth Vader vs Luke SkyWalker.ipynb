# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import random
import pickle

# %%
DIRECTORY=""
CATEGORIES = ["darth","luke"]
IMG_SIZE = 50

# %%
for category in CATEGORIES:
    path = os.path.join(DIRECTORY, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.imshow(img_array)
        plt.show()
        break
    break

# %%
print(img_array)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
IMG_SIZE = 100
new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
plt.imshow(new_array)
plt.show()

# %%
x_train = []
y_train = []

def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(DIRECTORY, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path,img)) 
            x_train.append([img_array])
            y_train.append([class_num])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_train = (x_train/255)
y_train = (y_train/255)

# %%
create_training_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-be131b356c3a> in <module>
# ----> 1 create_training_data()
#
# <ipython-input-6-7fbdaeda7e61> in create_training_data()
#       8         for img in os.listdir(path):
#       9             img_array = cv2.imread(os.path.join(path,img))
# ---> 10             x_train.append([img_array])
#      11             y_train.append([class_num])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
model = keras.Sequential([
    keras.layers.Flatten(),
    keras.layers.Dense(128,activation = "relu"),
    keras.layers.Dense(2, activation = "softmax")
                         ])

# %%
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics =["accuracy"])

# %%
model.fit(x_train, y_train, epochs = 10)
# Out:
# Epoch 1/10
